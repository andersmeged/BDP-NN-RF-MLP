# %%
#Import Pandas

import pandas as pd

#Import Databse (CSV), Seperate Columns, and Encode

df = pd.read_csv('master_dataset.csv', sep='\t', encoding='utf-8')

df.head()
# Out:
# C:\Users\Dazzpa\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (12,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1          _index _type         _id  \
# 0           0             0               0  cvr-v-20200115  _doc  4007585463
# 1           1             1               1  cvr-v-20200115  _doc  4007585463
# 2           2             2               2  cvr-v-20200115  _doc  4007585463
# 3           3             3               3  cvr-v-20200115  _doc  4007579859
# 4           4             4               4  cvr-v-20200115  _doc  4007579859
#
#    _score  _source.Vrvirksomhed.cvrNummer  \
# 0     1.0                        39457180
# 1     1.0                        39457180
# 2     1.0                        39457180
# 3     1.0                        39444054
# ...

# %%
#Overview of Dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273188 entries, 0 to 273187
# Data columns (total 55 columns):
#  #   Column                                                                                       Non-Null Count   Dtype
# ---  ------                                                                                       --------------   -----
#  0   Unnamed: 0                                                                                   273188 non-null  int64
#  1   Unnamed: 0.1                                                                                 273188 non-null  int64
#  2   Unnamed: 0.1.1                                                                               273188 non-null  int64
#  3   _index                                                                                       273188 non-null  object
#  4   _type                                                                                        273188 non-null  object
# ...

# %%
# Drop NaN Values and Subset Columns for Modelling Scope

df.dropna(subset = ["status", "branchekode", "_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.kommune.kommuneNavn"], inplace=True)
df
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1          _index _type  \
# 0                0             0               0  cvr-v-20200115  _doc
# 1                1             1               1  cvr-v-20200115  _doc
# 2                2             2               2  cvr-v-20200115  _doc
# 3                3             3               3  cvr-v-20200115  _doc
# 4                4             4               4  cvr-v-20200115  _doc
# ...            ...           ...             ...             ...   ...
# 273172       82271          1541            1541  cvr-v-20200115  _doc
# 273174       82273          1543            1543  cvr-v-20200115  _doc
# 273178       82277          1547            1547  cvr-v-20200115  _doc
# 273181       82280          1550            1550  cvr-v-20200115  _doc
# 273185       82284          1554            1554  cvr-v-20200115  _doc
#
#                _id  _score  _source.Vrvirksomhed.cvrNummer  \
# ...

# %%
#Renaming Columns for convenience

df = df.rename(columns=
           {'_index': 'index',
            '_type': 'type',
            '_id': 'id',
            '_score': 'score',
            '_source.Vrvirksomhed.virksomhedsstatus': 'vriksomhedsstatus',
            '_source.Vrvirksomhed.cvrNummer' : 'cvrNummer',
            '_source.Vrvirksomhed.hovedbranche' : 'hovedbranche',
            '_source.Vrvirksomhed.virksomhedMetadata.stiftelsesDato' : 'stiftelsesDato',
            '_source.Vrvirksomhed.virksomhedMetadata.sammensatStatus' : 'sammensatStatus',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteNavn.navn' : 'nyesteNavn',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.vejkode' : 'vejkode',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.fritekst' : 'nyesteBeliggenhedsadresseTekst',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.adresseId' : 'adresseId',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.vejnavn' : 'vejNavn',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.bogstavTil' : 'bagstavTil',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.conavn' : 'coNavn',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.bogstavFra' : 'bogstavFra',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.periode.gyldigFra' : 'gyldigFra',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.periode.gyldigTil' : 'gyldigTil',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.kommune.sidstOpdateret' : 'sidstOpdateret',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.kommune.kommuneNavn' : 'kommuneNavn',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.kommune.kommuneKode' : 'kommuneKode',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.kommune.periode.gyldigFra' : 'adresseGyldigFra',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.kommune.periode.gyldigTil' : 'adresseGyldigTil',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.husnummerFra' : 'husnummerFra',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.postboks' : 'postboks',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.sidstOpdateret' : 'sidstOpdateret',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.postnummer' : 'postnummer',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.etage' : 'etage',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.bynavn' : 'bynavn',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.husnummerTil' : 'husnummerTil',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.sidedoer' : 'sidedoer',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.landekode' : 'landeKode',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.sidstValideret' : 'sidstValideret',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.postdistrikt' : 'postDistrikt',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteVirksomhedsform.virksomhedsformkode' : 'virksomhedsformKode',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteVirksomhedsform.langBeskrivelse' : 'langBeskrivelse',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteVirksomhedsform.kortBeskrivelse' : 'kortBeskrivelse',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteVirksomhedsform.sidstOpdateret' : 'sidstOpdateret',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteVirksomhedsform.ansvarligDataleverandoer' : 'ansvarligDataleverandoer',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteVirksomhedsform.periode.gyldigFra' : 'virksomhedsformGyldigFra',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteVirksomhedsform.periode.gyldigTil' : 'virksomhedsformGyldigTil',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse' : 'nyesteBeliggenhedsadresse',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteVirksomhedsform' : 'nyesteVirksomhedsform',
            '_source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.kommune' : 'nyesteKommune'
           })

# %%
#Overview of the different Kortbeskrivelse

df['kortBeskrivelse'].value_counts()
# Out:
# APS    97750
# IVS    33765
# A/S     3428
# K/S      837
# KAS      618
# FAP      381
# FAS      315
# I/S      216
# EFO      102
# FMA       69
# ABA       28
# FBA       15
# FIV       10
# SCE        2
# FOR        1
# MSS        1
# Name: kortBeskrivelse, dtype: int64

# %%
#Replace Kortbeskrivelse with APS (1) vs Non-APS (0)

df = df.replace({'IVS': 0})
df = df.replace({'K/S': 0})
df = df.replace({'APS': 1})
df = df.replace({'A/S': 0})
df = df.replace({'KAS': 0})
df = df.replace({'FAP': 0})
df = df.replace({'EFO': 0})
df = df.replace({'I/S': 0})
df = df.replace({'FAS': 0})
df = df.replace({'FMA': 0})
df = df.replace({'FBA': 0})
df = df.replace({'ABA': 0})
df = df.replace({'FIV': 0})
df = df.replace({'SCE': 0})
df = df.replace({'MSS': 0})
df = df.replace({'FOR': 0})

# %%
# Current Split of APS (1) vs Non-APS (0)

df['kortBeskrivelse'].value_counts()
# Out:
# 1    97750
# 0    39788
# Name: kortBeskrivelse, dtype: int64

# %%
#Overview of Status Counts

df['status'].value_counts()
# Out:
# NORMAL                                                111645
# UNDER TVANGSOPLØSNING                                   8239
# UDEN RETSVIRKNING                                       4243
# UNDER KONKURS                                           3973
# OPLØST EFTER ERKLÆRING                                  3528
# TVANGSOPLØST                                            2355
# OPLØST EFTER KONKURS                                    1250
# OPLØST EFTER SPALTNING                                   730
# UNDER FRIVILLIG LIKVIDATION                              525
# OPLØST EFTER FUSION                                      525
# SLETTET                                                  272
# OPLØST EFTER FRIVILLIG LIKVIDATION                       240
# UNDER REKONSTRUKTION                                       8
# UNDER REASSUMERING                                         4
# OPLØST EFTER GRÆNSEOVERSKRIDENDE HJEMSTEDSFLYTNING         1
# Name: status, dtype: int64

# %%
#Replace Status with 1 (Open or Closed, without issues) vs 0 (Closed, with issues)

df = df.replace({'Aktiv': 1})
df = df.replace({'NORMAL': 1})
df = df.replace({'OPLØST EFTER ERKLÆRING': 1})
df = df.replace({'OPLØST EFTER FRIVILLIG LIKVIDATION': 0})
df = df.replace({'OPLØST EFTER FUSION': 1})
df = df.replace({'OPLØST EFTER GRÆNSEOVERSKRIDENDE HJEMSTEDSFLYTNING': 1})
df = df.replace({'OPLØST EFTER KONKURS': 0})
df = df.replace({'OPLØST EFTER SPALTNING': 0})
df = df.replace({'SLETTET': 0})
df = df.replace({'TVANGSOPLØST': 0})
df = df.replace({'UDEN RETSVIRKNING': 0})
df = df.replace({'UNDER FRIVILLIG LIKVIDATION': 0})
df = df.replace({'UNDER KONKURS': 0})
df = df.replace({'UNDER REASSUMERING': 0})
df = df.replace({'UNDER REKONSTRUKTION': 1})
df = df.replace({'UNDER TVANGSOPLØSNING': 0})

# %%
# Current Split of Non-Support-Status (1) vs Support-Status (0)

df['status'].value_counts()
# Out:
# 1    115707
# 0     21831
# Name: status, dtype: int64

# %%
neg = len(df[df['status'] == 0])
pos = len(df[df['status'] == 1]) 
total = df['status'].count()
print(neg)
print(pos)
# Out:
# 21831
# 115707

# %%
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 3.15
# Weight for class 1: 0.59

# %%
#Covert Dateframe into Year, Month, and Day

df['date_time']=pd.to_datetime(df['stiftelsesDato'], format='%Y-%m-%d')

#Create two new columns, one for the year and one for the month
df['Day_year'] = df['date_time'].dt.year
df['Day_month'] = df['date_time'].dt.month

# %%
#Specifying X and y Variables
X=df[['branchekode','kommuneKode','Day_year','Day_month','kortBeskrivelse']]
y=df['status'].values

# %%
# Import Preprocessing
from sklearn import preprocessing

# Import TrainTestSplit
from sklearn.model_selection import train_test_split

#Do Split (80% Train, 20% Test)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn import tree

# Import BaggingClassifier
from sklearn.ensemble import BaggingClassifier

# Import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# Instantiate DT
dt = DecisionTreeClassifier(random_state=1,class_weight = class_weight)
dt2 = tree.DecisionTreeRegressor(max_depth=3, min_samples_split=2, random_state=1)

# Instantiate BC
bc = BaggingClassifier(base_estimator=dt, n_estimators=1000, random_state=1)
bc
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight={0: 3.1500618386697816,
#                                                                       1: 0.5943374212450413},
#                                                         random_state=1),
#                   n_estimators=1000, random_state=1)

# %%
from sklearn import tree

# %%
dt2.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=1)

# %%
import matplotlib.pyplot as plt
classnames = ['branchekode','kommuneKode','Day_year','Day_month','kortBeskrivelse']
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt2,filled=True,feature_names=classnames)

plt.show()

# %%
#Import AccuracyScore

from sklearn.metrics import accuracy_score

# Fit bc to Train Set
bc.fit(X_train, y_train)
# Predict Test Set
y_pred = bc.predict(X_test)
# Evaluate Accuracy
acc_test = accuracy_score(y_test, y_pred)
print('Test set accuracy of bc: {:.2f}'.format(acc_test))
# Out:
# Test set accuracy of bc: 0.78

# %%
#Import ConfusionMatrix, Seaborn, Matplotlib and Numpy

from sklearn.metrics import confusion_matrix
import seaborn as sn
import numpy as np 
# %matplotlib inline

#Plot ConfustionMatrix

data = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(data, columns=np.unique(y_test), index = np.unique(y_test))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})# font size
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
# Import RandomForest

from sklearn.ensemble import RandomForestRegressor

# Instantiate RF
rf = RandomForestRegressor(n_estimators=100, random_state=1)

# %%
# Fit RF to Train Set

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
# Import MeanSquareError

from sklearn.metrics import mean_squared_error as MSE

# Predict Test Set
y_pred = rf.predict(X_test)

# Evaluate the test set MSE
rmse_test = MSE(y_test, y_pred)**(1/2)

# Print MSE
print('Test set MSE of rf: {:.2f}'.format(rmse_test))
# Out:
# Test set MSE of rf: 0.38

# %%
# Create a pd.Series of Feature Importance

importances = pd.Series(data=rf.feature_importances_,
                        index= X_train.columns)
# Sort Feature Importance

importances_sorted = importances.sort_values()

# Plot Feature Importance

importances_sorted.plot(kind='barh', color='blue')
plt.title('Feature Importance')
plt.show()

# %%
# Import AdaBoostClassifier

from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier(base_estimator=dt, n_estimators=100, random_state=1)

# %%
# Fit ada to the training set
ada.fit(X_train, y_train)
# Compute the probabilities of obtaining the positive class

y_pred_proba  = ada.predict_proba(X_test)[:,1]

# %%
# Import roc_auc_score
from sklearn.metrics import roc_auc_score

# Evaluate test-set roc_auc_score
ada_roc_auc = roc_auc_score(y_test, y_pred_proba)

# Print roc_auc_score
print('ROC AUC score: {:.2f}'.format(ada_roc_auc))
# Out:
# ROC AUC score: 0.70
