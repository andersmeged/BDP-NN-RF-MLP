# %%
import json
import pandas as pd
from pandas.io.json import json_normalize


with open('r1.json', encoding='UTF-8') as f:
    d = json.load(f)
evd = json_normalize(d['hits']['hits'])
evd_vf = json_normalize(d['hits']['hits'], record_path=['_source', 'Vrvirksomhed', 'virksomhedsform'], meta=['_id'])
evd_hb = json_normalize(d['hits']['hits'], record_path=['_source', 'Vrvirksomhed', 'hovedbranche'], meta=['_id'])
e_merge = pd.merge(evd, evd_vf, on='_id', how='inner')
evd_master = pd.merge(e_merge, evd_hb, on='_id', how='inner')
evd_master = evd_master.drop(columns=['_source.Vrvirksomhed.virksomhedsform', '_source.Vrvirksomhed.hovedbranche'])
#evd_master.to_csv('evd1.csv', sep='\t', encoding='utf-8')

evd_master
# Out:
# C:\Users\ander\anaconda3\envs\BDP\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# C:\Users\ander\anaconda3\envs\BDP\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
# C:\Users\ander\anaconda3\envs\BDP\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # Remove the CWD from sys.path while we load stuff.
#               _index _type         _id  _score  \
# 0     cvr-v-20200115  _doc  4008372500     1.0
# 1     cvr-v-20200115  _doc  4008409427     1.0
# 2     cvr-v-20200115  _doc  4008416476     1.0
# 3     cvr-v-20200115  _doc  4008413656     1.0
# 4     cvr-v-20200115  _doc  4008425322     1.0
# ...              ...   ...         ...     ...
# 2831  cvr-v-20200115  _doc  4008410112     1.0
# 2832  cvr-v-20200115  _doc  4008418195     1.0
# 2833  cvr-v-20200115  _doc  4008416407     1.0
# 2834  cvr-v-20200115  _doc  4008413553     1.0
# 2835  cvr-v-20200115  _doc  4008416479     1.0
#
#       _source.Vrvirksomhed.cvrNummer  \
# 0                           41185589
# 1                           41276134
# 2                           41291079
# 3                           41285966
# 4                           41296674
# ...                              ...
# 2831                        41278137
# 2832                        41298162
# 2833                        41293764
# 2834                        41285990
# 2835                        41291060
#
#      _source.Vrvirksomhed.virksomhedMetadata.stiftelsesDato  \
# 0                                            2020-04-01
# 1                                            2020-04-02
# 2                                            2020-04-13
# 3                                            2020-04-08
# 4                                            2020-04-01
# ...                                                 ...
# 2831                                         2020-04-02
# 2832                                         2020-04-15
# 2833                                         2020-04-06
# 2834                                         2020-04-08
# 2835                                         2020-04-13
#
#      _source.Vrvirksomhed.virksomhedMetadata.nyesteNavn.navn  \
# 0                                 IT-SupportKonsulenten
# 1                                     fruittella gelato
# 2                                    Trappevaskeren I/S
# 3                                              33604432
# 4                                  Konsulent Laila Tang
# ...                                                 ...
# 2831                                      Mossø Byg ApS
# 2832                                   RZSG Holding ApS
# 2833                                      Fadbamsen I/S
# 2834  ArcelorMittal, filial af ArcelorMittal Belgium...
# 2835                                       eric currier
#
#       _source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.vejkode  \
# 0                                                   489
# 1                                                   220
# 2                                                  3456
# 3                                                  2810
# 4                                                   524
# ...                                                 ...
# 2831                                               1017
# 2832                                               3468
# 2833                                               6623
# 2834                                                305
# 2835                                               8398
#
#      _source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.fritekst  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 2831                                               None
# 2832                                               None
# 2833                                               None
# 2834                                               None
# 2835                                               None
#
#      _source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.adresseId  \
# 0                  0a3f50ad-3a9e-32b8-e044-0003ba298018
# 1                  7896a9ec-ac0d-40f5-b4b0-5c08b2e99730
# 2                  0a3f509f-0eea-32b8-e044-0003ba298018
# 3                  0a3f50be-d623-32b8-e044-0003ba298018
# 4                  0a3f50a4-cc94-32b8-e044-0003ba298018
# ...                                                 ...
# 2831               0a3f50c2-40b5-32b8-e044-0003ba298018
# 2832               0a3f509f-1279-32b8-e044-0003ba298018
# 2833               0a3f50ca-8c6d-32b8-e044-0003ba298018
# 2834               76254484-be22-4ae3-986e-8deede27e739
# 2835               0a3f50a1-bdf8-32b8-e044-0003ba298018
#
#       ... kortBeskrivelse               sidstOpdateret_x  \
# 0     ...             ENK  2020-04-03T09:33:15.000+02:00
# 1     ...             ENK  2020-04-10T18:06:33.000+02:00
# 2     ...             I/S  2020-04-20T12:16:49.000+02:00
# 3     ...             FFO  2020-05-05T15:13:52.000+02:00
# 4     ...             ENK  2020-05-01T15:07:29.000+02:00
# ...   ...             ...                            ...
# 2831  ...             APS  2020-04-03T13:31:51.000+02:00
# 2832  ...             APS  2020-04-16T14:29:00.000+02:00
# 2833  ...             I/S  2020-04-15T09:16:45.000+02:00
# 2834  ...             FAS  2020-04-08T11:04:25.000+02:00
# 2835  ...             ENK  2020-04-15T09:24:36.000+02:00
#
#      ansvarligDataleverandoer periode.gyldigFra_x periode.gyldigTil_x  \
# 0                         T&S          2020-04-01          2020-04-01
# 1                         T&S          2020-04-02          2020-04-10
# 2                         T&S          2020-04-13          2020-04-20
# 3                         T&S          2020-04-08          2020-05-05
# 4                         T&S          2020-04-01          2020-04-30
# ...                       ...                 ...                 ...
# 2831                      E&S          2020-04-02                None
# 2832                      E&S          2020-04-15                None
# 2833                      T&S          2020-04-06                None
# 2834                      E&S          2020-04-08                None
# 2835                      T&S          2020-04-13                None
#
#                    sidstOpdateret_y  \
# 0     2020-04-03T09:33:15.000+02:00
# 1     2020-04-10T18:06:33.000+02:00
# 2     2020-04-20T12:16:49.000+02:00
# 3     2020-05-05T15:13:52.000+02:00
# 4     2020-05-01T15:07:29.000+02:00
# ...                             ...
# 2831  2020-04-03T13:31:51.000+02:00
# 2832  2020-04-16T14:29:00.000+02:00
# 2833  2020-04-15T09:16:45.000+02:00
# 2834  2020-04-08T11:04:25.000+02:00
# 2835  2020-04-15T09:24:36.000+02:00
#
#                                            branchetekst branchekode  \
# 0     Konsulentbistand vedrørende informationsteknologi      620200
# 1                              Fremstilling af konsumis      105200
# 2                            Kombinerede serviceydelser      811000
# 3             Andre organisationer og foreninger i.a.n.      949900
# 4     Konsulentbistand vedrørende informationsteknologi      620200
# ...                                                 ...         ...
# 2831                         Anden udlejning af boliger      682030
# 2832                  Ikke-finansielle holdingselskaber      642020
# 2833                  Cafeér, værtshuse, diskoteker mv.      563000
# 2834  Fremstilling af andre færdige metalprodukter i...      259900
# 2835                      Andre post- og kurertjenester      532000
#
#       periode.gyldigFra_y periode.gyldigTil_y
# 0              2020-04-01          2020-04-01
# 1              2020-04-02          2020-04-10
# 2              2020-04-13          2020-04-20
# 3              2020-04-08          2020-05-05
# 4              2020-04-01          2020-04-30
# ...                   ...                 ...
# 2831           2020-04-02                None
# 2832           2020-04-15                None
# 2833           2020-04-06                None
# 2834           2020-04-08                None
# 2835           2020-04-13                None
#
# [2836 rows x 44 columns]

# %%
import pandas as pd
df = pd.read_csv('evd0.csv', sep='\t', encoding='utf-8')
df.drop(df.index, inplace=True)

#New cell for loading all the csv files into dataframes
import pandas as pd
df0 = pd.read_csv('evd0.csv', sep='\t', encoding='utf-8')
df1 = pd.read_csv('evd1.csv', sep='\t', encoding='utf-8')
df2 = pd.read_csv('evd2.csv', sep='\t', encoding='utf-8')
df3 = pd.read_csv('evd3.csv', sep='\t', encoding='utf-8')
df4 = pd.read_csv('evd4.csv', sep='\t', encoding='utf-8')
df5 = pd.read_csv('evd5.csv', sep='\t', encoding='utf-8')
df6 = pd.read_csv('evd6.csv', sep='\t', encoding='utf-8')
df7 = pd.read_csv('evd7.csv', sep='\t', encoding='utf-8')
df8 = pd.read_csv('evd8.csv', sep='\t', encoding='utf-8')
df9 = pd.read_csv('evd9.csv', sep='\t', encoding='utf-8')
df10 = pd.read_csv('evd10.csv', sep='\t', encoding='utf-8')
df11 = pd.read_csv('evd11.csv', sep='\t', encoding='utf-8')
df12 = pd.read_csv('evd12.csv', sep='\t', encoding='utf-8')
df13 = pd.read_csv('evd13.csv', sep='\t', encoding='utf-8')
df14 = pd.read_csv('evd14.csv', sep='\t', encoding='utf-8')
df15 = pd.read_csv('evd15.csv', sep='\t', encoding='utf-8')
df16 = pd.read_csv('evd16.csv', sep='\t', encoding='utf-8')
df17 = pd.read_csv('evd17.csv', sep='\t', encoding='utf-8')
df18 = pd.read_csv('evd18.csv', sep='\t', encoding='utf-8')
df19 = pd.read_csv('evd19.csv', sep='\t', encoding='utf-8')
df20 = pd.read_csv('evd20.csv', sep='\t', encoding='utf-8')
df21 = pd.read_csv('evd21.csv', sep='\t', encoding='utf-8')
df22 = pd.read_csv('evd22.csv', sep='\t', encoding='utf-8')
df23 = pd.read_csv('evd23.csv', sep='\t', encoding='utf-8')
df24 = pd.read_csv('evd24.csv', sep='\t', encoding='utf-8')
df25 = pd.read_csv('evd25.csv', sep='\t', encoding='utf-8')
df26 = pd.read_csv('evd26.csv', sep='\t', encoding='utf-8')
df27 = pd.read_csv('evd27.csv', sep='\t', encoding='utf-8')

# %%
#New sell for merging the data frames
df = df.append(df0)
df = df.append(df1)
df = df.append(df2)
df = df.append(df3)
df = df.append(df4)
df = df.append(df5)
df = df.append(df6)
df = df.append(df7)
df = df.append(df8)
df = df.append(df9)
df = df.append(df10)
df = df.append(df11)
df = df.append(df12)
df = df.append(df13)
df = df.append(df14)
df = df.append(df15)
df = df.append(df16)
df = df.append(df17)
df = df.append(df18)
df = df.append(df19)
df = df.append(df20)
df = df.append(df21)
df = df.append(df22)
df = df.append(df23)
df = df.append(df24)
df = df.append(df25)
df = df.append(df26)
df = df.append(df27)
df
# Out:
#       Unnamed: 0          _index _type         _id  _score  \
# 0              0  cvr-v-20200115  _doc  4008398273     1.0
# 1              1  cvr-v-20200115  _doc  4008404946     1.0
# 2              2  cvr-v-20200115  _doc  4008398119     1.0
# 3              3  cvr-v-20200115  _doc  4008397486     1.0
# 4              4  cvr-v-20200115  _doc  4008394401     1.0
# ...          ...             ...   ...         ...     ...
# 1144        1144  cvr-v-20200115  _doc  4008780677     1.0
# 1145        1145  cvr-v-20200115  _doc  4008780667     1.0
# 1146        1146  cvr-v-20200115  _doc  4008780488     1.0
# 1147        1147  cvr-v-20200115  _doc  4008780551     1.0
# 1148        1148  cvr-v-20200115  _doc  4008780524     1.0
#
#       _source.Vrvirksomhed.cvrNummer  \
# 0                           41252936
# 1                           41267151
# 2                           41252030
# 3                           41250976
# 4                           41240881
# ...                              ...
# 1144                        42177962
# 1145                        42177946
# 1146                        42176885
# 1147                        42177652
# 1148                        42177571
#
#      _source.Vrvirksomhed.virksomhedMetadata.stiftelsesDato  \
# 0                                            2020-03-21
# 1                                            2020-03-30
# 2                                            2020-03-20
# 3                                            2020-03-19
# 4                                            2020-03-16
# ...                                                 ...
# 1144                                         2021-03-02
# 1145                                         2021-03-02
# 1146                                         2021-03-03
# 1147                                         2021-03-01
# 1148                                         2021-03-01
#
#      _source.Vrvirksomhed.virksomhedMetadata.nyesteNavn.navn  \
# 0                                               PC Help
# 1                                      Odium RetshjÃ¦lp
# 2                                            Kunstpause
# 3                                  5 Stars Services ApS
# 4                                        Rye RengÃ¸ring
# ...                                                 ...
# 1144                       Inductive Energy Holding ApS
# 1145                                 Krom Auktioner ApS
# 1146                                  Aira Translations
# 1147                                  Wollerup Stuk ApS
# 1148                             Crashpoint Holding ApS
#
#       _source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.vejkode  \
# 0                                                 713.0
# 1                                                 605.0
# 2                                                3711.0
# 3                                                 850.0
# 4                                                  25.0
# ...                                                 ...
# 1144                                             8215.0
# 1145                                             6112.0
# 1146                                             1229.0
# 1147                                              595.0
# 1148                                              495.0
#
#       _source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.fritekst  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1144                                                NaN
# 1145                                                NaN
# 1146                                                NaN
# 1147                                                NaN
# 1148                                                NaN
#
#       ... ansvarligDataleverandoer periode.gyldigFra_x periode.gyldigTil_x  \
# 0     ...                      T&S          2020-03-21          2020-03-26
# 1     ...                      T&S          2020-03-30          2020-05-22
# 2     ...                      T&S          2020-03-20          2020-05-30
# 3     ...                      E&S          2020-03-19          2020-06-03
# 4     ...                      T&S          2020-03-16          2020-05-04
# ...   ...                      ...                 ...                 ...
# 1144  ...                      E&S          2021-03-02                 NaN
# 1145  ...                      E&S          2021-03-02                 NaN
# 1146  ...                      T&S          2021-03-03                 NaN
# 1147  ...                      E&S          2021-03-01                 NaN
# 1148  ...                      E&S          2021-03-01                 NaN
#
#                    sidstOpdateret_y  \
# 0     2020-03-26T18:09:04.000+01:00
# 1     2020-05-22T09:06:34.000+02:00
# 2     2020-05-30T15:05:32.000+02:00
# 3     2020-06-03T14:26:58.000+02:00
# 4     2020-05-04T09:08:22.000+02:00
# ...                             ...
# 1144  2021-03-03T11:03:25.000+01:00
# 1145  2021-03-03T11:00:25.000+01:00
# 1146  2021-03-03T10:03:47.000+01:00
# 1147  2021-03-03T10:34:08.000+01:00
# 1148  2021-03-03T10:20:11.000+01:00
#
#                                            branchetekst branchekode  \
# 0     Konsulentbistand vedrÃ¸rende informationstekno...      620200
# 1             Andre organisationer og foreninger i.a.n.      949900
# 2             Andre organisationer og foreninger i.a.n.      949900
# 3                         Anden bygningsfÃ¦rdiggÃ¸relse      433900
# 4                     Almindelig rengÃ¸ring i bygninger      812100
# ...                                                 ...         ...
# 1144                  Ikke-finansielle holdingselskaber      642020
# 1145       Detailhandel med brugte varer i forretninger      477900
# 1146                           Oversættelse og tolkning      743000
# 1147                                Stukkatørvirksomhed      433100
# 1148                  Ikke-finansielle holdingselskaber      642020
#
#      periode.gyldigFra_y periode.gyldigTil_y  \
# 0             2020-03-21          2020-03-26
# 1             2020-03-30          2020-05-22
# 2             2020-03-20          2020-05-30
# 3             2020-03-19          2020-06-03
# 4             2020-03-16          2020-05-04
# ...                  ...                 ...
# 1144          2021-03-02                 NaN
# 1145          2021-03-02                 NaN
# 1146          2021-03-03                 NaN
# 1147          2021-03-01                 NaN
# 1148          2021-03-01                 NaN
#
#      _source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1144                                                NaN
# 1145                                                NaN
# 1146                                                NaN
# 1147                                                NaN
# 1148                                                NaN
#
#       _source.Vrvirksomhed.virksomhedMetadata.nyesteBeliggenhedsadresse.kommune
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1144                                                NaN
# 1145                                                NaN
# 1146                                                NaN
# 1147                                                NaN
# 1148                                                NaN
#
# [79464 rows x 47 columns]

# %%
df.to_csv('evd_master.csv', sep='\t', encoding='utf-8')
